# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
### Training project

# Function to read convergence history data from file
def read_convergence_history(filename):
    iterations = []
    costs = []
    with open(filename, 'r') as file:
        for line in file:
            if line.strip():  # Skip empty lines
                iteration, cost = map(float, line.split())
                iterations.append(int(iteration))
                costs.append(cost)
    return iterations, costs

# Read the convergence history data
filename = 'convergence_history_simple.txt'
iterations, costs = read_convergence_history(filename)

# Plot the convergence history
plt.figure(figsize=(10, 6))
plt.plot(iterations, costs, label='Cost')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.title('Convergence History')
plt.legend()

# %%
### 2, 4, 4, 1 NN

# Function to read convergence history data from file
def read_convergence_history(filename):
    iterations = []
    costs = []
    with open(filename, 'r') as file:
        for line in file:
            if line.strip():  # Skip empty lines
                iteration, cost = map(float, line.split())
                iterations.append(int(iteration))
                costs.append(cost)
    return iterations, costs

# Read the convergence history data
filename = 'convergence_history.txt'
iterations, costs = read_convergence_history(filename)

# Plot the convergence history
plt.figure(figsize=(10, 6))
plt.plot(iterations, costs, label='Cost')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.title('Convergence History')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 17
#      15 # Read the convergence history data
#      16 filename = 'convergence_history.txt'
# ---> 17 iterations, costs = read_convergence_history(filename)
#      19 # Plot the convergence history
#      20 plt.figure(figsize=(10, 6))
#
# Cell In[26], line 7, in read_convergence_history(filename)
#       5 iterations = []
#       6 costs = []
# ----> 7 with open(filename, 'r') as file:
#       8     for line in file:
#       9         if line.strip():  # Skip empty lines
#
# File c:\Users\Gegenubr\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'convergence_history.txt'

# %%
### 2, 4, 4, 4, 1 NN

# Function to read convergence history data from file
def read_convergence_history(filename):
    iterations = []
    costs = []
    with open(filename, 'r') as file:
        for line in file:
            if line.strip():  # Skip empty lines
                iteration, cost = map(float, line.split())
                iterations.append(int(iteration))
                costs.append(cost)
    return iterations, costs

# Read the convergence history data
filename = 'convergence_history_spiral (2, 4, 4, 4, 1).txt'
iterations, costs = read_convergence_history(filename)

# Plot the convergence history
plt.figure(figsize=(10, 6))
plt.plot(iterations, costs, label='Cost')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.title('Convergence History')
plt.legend()

# %%
### 2, 4, 4, 4, 4, 1 NN

# Function to read convergence history data from file
def read_convergence_history(filename):
    iterations = []
    costs = []
    with open(filename, 'r') as file:
        for line in file:
            if line.strip():  # Skip empty lines
                iteration, cost = map(float, line.split())
                iterations.append(int(iteration))
                costs.append(cost)
    return iterations, costs

# Read the convergence history data
filename = 'convergence_history_sprial (2, 4, 4, 4, 4, 1).txt'
iterations, costs = read_convergence_history(filename)

# Plot the convergence history
plt.figure(figsize=(10, 6))
plt.plot(iterations, costs, label='Cost')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.title('Convergence History')
plt.legend()

# %%
### 2, 16, 16, 1 NN

# Function to read convergence history data from file
def read_convergence_history(filename):
    iterations = []
    costs = []
    with open(filename, 'r') as file:
        for line in file:
            if line.strip():  # Skip empty lines
                iteration, cost = map(float, line.split())
                iterations.append(int(iteration))
                costs.append(cost)
    return iterations, costs

# Read the convergence history data
filename = 'convergence_history_spiral (2, 16, 16, 1).txt'
iterations, costs = read_convergence_history(filename)

# Plot the convergence history
plt.figure(figsize=(10, 6))
plt.plot(iterations, costs, label='Cost')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.title('Convergence History')
plt.legend()

# %%
# Load training data

training_data = np.loadtxt("project_training_data_plotting.dat")

X_train = training_data[:, :2]  # First two columns: inputs
y_train = training_data[:, 2]   # Last column: target outputs

# Load boundary data
boundary_data = np.loadtxt("boundary_data_simple.txt")
X1, X2, outputs = boundary_data[:, 0], boundary_data[:, 1], boundary_data[:, 2]

# Reshape boundary data for contour plot
X1_grid = X1.reshape(100, 100)
X2_grid = X2.reshape(100, 100)
outputs_grid = outputs.reshape(100, 100)

# Plot decision boundary
plt.contour(X1_grid, X2_grid, outputs_grid, levels=[0.5], colors='black', linewidths=2)

# Plot training data
plt.scatter(X_train[y_train == -1, 0], X_train[y_train == -1, 1], color='blue', label='Blue')
plt.scatter(X_train[y_train == 1, 0], X_train[y_train == 1, 1], color='red', label='Red')

plt.legend()

# %%
# NN 2, 4, 4, 4, 1

training_data = np.loadtxt("spiral_training_data_plotting.dat")

X_train = training_data[:, :2]  # First two columns: inputs
y_train = training_data[:, 2]   # Last column: target outputs

# Load boundary data
boundary_data = np.loadtxt("boundary_data_spiral (2, 16, 16, 1).txt")
X1, X2, outputs = boundary_data[:, 0], boundary_data[:, 1], boundary_data[:, 2]

# Reshape boundary data for contour plot
X1_grid = X1.reshape(100, 100)
X2_grid = X2.reshape(100, 100)
outputs_grid = outputs.reshape(100, 100)

# Plot decision boundary
plt.contour(X1_grid, X2_grid, outputs_grid, levels=[0.5], colors='black', linewidths=2)

# Plot training data
plt.scatter(X_train[y_train == -1, 0], X_train[y_train == -1, 1], color='blue', label='Blue')
plt.scatter(X_train[y_train == 1, 0], X_train[y_train == 1, 1], color='red', label='Red')

plt.legend()
